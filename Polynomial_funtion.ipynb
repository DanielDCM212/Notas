# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielDCM212/Notas/blob/main/Polynomial_funtion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Polynomial Funtion
#
# Funcion a ajustar
#
# $y(x,w) = w_{0} + w_{2}x^{2} + ... w_{M}x^{M}$
#
# $\sum_{j=0}^{n} w_{j}x^{i}$
#
# M is the polynomial ortder and w is the polynomial coefficients vertor w = .......
#
# The error functuin is giving by:
#
# $E(w) = \frac{1}{2}\sum_{n=1}^{N}\{y(x_{n},w)-t_{n}\}^{2}$
#
# $E(w) = \frac{1}{2}\sum_{n=1}^{N}\{w_{0}+ w_{1}x_{n} + w_{2}x_{n}^{2} + ... w_{M}x_{n}^{M}-t_{n}\}^{2}$
#
#
# /Imagen/
#
#
# Sometimes it's not enought to set $\frac{dy(n)}{dt}= 0$ to find the x value such that y(x) is minimum
#
# /img2/
#
# To minimice $F(w)$, it is needed to take the derivative of $ec(u)$ with re.... to each unkown coefficient $(w_{0},w_{1},...,w_{m})$.
#
# $\frac{\partial E(w)}{\partial w_{0}} = \frac{\partial}{\partial w_{0}} [\frac{1}{2}\sum_{n=1}^{N}\{w_{0} +w_{1}x_{n}+ w_{2}x_{n}^{2} + ... w_{M}x_{n}^{M}-t_{n}\}^{2}]$
#
#
# $\frac{\partial E(w)}{\partial w_{0}} = \frac{1}{2} 2 \sum_{n=1}^{N}\{w_{0} + w_{1}x_{n} + w_{2}x_{n}^{2} + ... w_{M}x_{n}^{M}-t_{n}\}(1)$
#
# $\frac{\partial E(w)}{\partial w_{1}} = \frac{\partial}{\partial w_{1}} [\frac{1}{2}\sum_{n=1}^{N}\{w_{0} +w_{1}x_{n}+ w_{2}x_{n}^{2} + ... w_{M}x_{n}^{M}-t_{n}\}^{2}]$
#
# $\frac{\partial E(w)}{\partial w_{1}} = \frac{1}{2} 2 \sum_{n=1}^{N}\{w_{0} + w_{1}x_{n} + w_{2}x_{n}^{2} + ... w_{M}x_{n}^{M}-t_{n}\}(x_{n})$
#
# -------
#
# ## Note
#
# ----------
#
# Now, we will rewrite alll derivation as follows:
#
#
# $\frac{\partial E(w)}{\partial w_{0}} = \frac{1}{2} 2 \sum_{n=1}^{N}\{w_{0} + w_{1}x_{n} + w_{2}x_{n}^{2} + ... w_{M}x_{n}^{M}-t_{n}\}(1) = 0$
#
# $\frac{\partial E(w)}{\partial w_{1}} = \frac{1}{2} 2 \sum_{n=1}^{N}\{w_{0} + w_{1}x_{n} + w_{2}x_{n}^{2} + ... w_{M}x_{n}^{M}-t_{n}\}x_{n} = 0$
#
# $\frac{\partial E(w)}{\partial w_{2}} = \frac{1}{2} 2 \sum_{n=1}^{N}\{w_{0} + w_{1}x_{n} + w_{2}x_{n}^{2} + ... w_{M}x_{n}^{M}-t_{n}\}x_{n}^{2} = 0$
#
# ....
#
# $\frac{\partial E(w)}{\partial w_{m}} = \frac{1}{2} 2 \sum_{n=1}^{N}\{w_{0} + w_{1}x_{n} + w_{2}x_{n}^{2} + ... w_{M}x_{n}^{M}-t_{n}\}x_{n}^{m} = 0$
#
# ------------------
#
# $\sum_{i=1}^{N} = 1+2+...+N = \frac{N(N+1)}{2}$
#
# $\sum_{i=1}^{N}2i = 2 + 4 + 6 + ... + 2N$
#
# $=2(1+2+3+...+N)$
#
# $2\sum_{i=1}^{N}i = 2\frac{N(N+1)}{2}$
#
#
#
# --------
#
# \IMG4\
#
# -------
# The x lead to the following equations:
#
# $\frac{\partial E(w)}{\partial w_{0}} = w_{0}\sum_{n=1}^{N} 1 + w_{1} \sum_{n=1}^{N} x_{n} + w_{2}\sum_{n=1}^{N} x_{n}^{2}+ ... + w_{M} \sum_{n=1}^{N}x_{n}^{w} - \sum_{n=1}^{N}t_{n}=0$
#
#
#
# $\frac{\partial E(w)}{\partial w_{1}} = w_{0}\sum_{n=1}^{N} x_{n} + w_{1} \sum_{n=1}^{N} x_{n}^{2} + w_{2}\sum_{n=1}^{N} x_{n}^{3}+ ... + w_{M} \sum_{n=1}^{N}x_{n}^{w+1} - \sum_{n=1}^{N}t_{n}x_{n}=0$
#
#
# $\frac{\partial E(w)}{\partial w_{2}} = w_{0}\sum_{n=1}^{N} x_{n}^{2} + w_{1} \sum_{n=1}^{N} x_{n}^{3} + w_{2}\sum_{n=1}^{N} x_{n}^{4}+ ... + w_{M} \sum_{n=1}^{N}x_{n}^{w+2} - \sum_{n=1}^{N}t_{n}x_{n}^{2}=0$
#
# ........
#
#
# $\frac{\partial E(w)}{\partial w_{m}} = w_{0}\sum_{n=1}^{N} x_{0}^{M} + w_{1} \sum_{n=1}^{N} x_{n}^{M+1} + w_{2}\sum_{n=1}^{N} x_{n}^{M+2}+ ... + w_{M} \sum_{n=1}^{N}x_{n}^{M+M} - \sum_{n=1}^{N}t_{n}x_{n}^{M}=0$
#
# --------
#
# $\begin{bmatrix}
# 1 & 2 \\
# 3 & 4
# \end{bmatrix}
# \begin{bmatrix}
# a \\
# b
# \end{bmatrix}
# =
# \begin{bmatrix}
# 1a & 2b \\
# 3a & 4b
# \end{bmatrix}
# =
# \begin{bmatrix}
# a1 & b2 \\
# a3 & b4
# \end{bmatrix}
# $
#
#
# ----------
#
# $\begin{bmatrix}
# \sum_{n=1}^{N} 1 & \sum_{n=1}^{N} x_{n} & \sum_{n=1}^{N} x_{n}^2 & ... & \sum_{n=1}^{N} x_{n}^{M} \\
# \sum_{n=1}^{N} x_{n} & \sum_{n=1}^{N} x_{n}^2 & \sum_{n=1}^{N} x_{n}^3 & ... & \sum_{n=1}^{N} x_{n}^{M+1}
# \\
# \sum_{n=1}^{N} x_{n}^2 & \sum_{n=1}^{N} x_{n}^3 & \sum_{n=1}^{N} x_{n}^4 & ... & \sum_{n=1}^{N} x_{n}^{M+2}
# \\
# . & . & . & . & .
# \\
# . & . & . & . & .
# \\
# . & . & . & . & .
# \\
# \sum_{n=1}^{N} x_{n}^M & \sum_{n=1}^{N} x_{n}^{M+1} & \sum_{n=1}^{N} x_{n}^{M+2} & ... & \sum_{n=1}^{N} x_{n}^{2M}
# \end{bmatrix}
# $
# $
# \begin{bmatrix}
# w_{0} \\
# w_{1} \\
# w_{2} \\
# . \\
# . \\
# . \\
# w_{M} \\
# \end{bmatrix}
# $
# $
# =\begin{bmatrix}
# \sum_{n=1}^{N} t_{n} \\
# \sum_{n=1}{N} t_{n}x_{n} \\
# \sum_{n=1}{N} t_{n}x_{n}^{2} \\
# . \\
# \sum_{n=1}{N} t_{n}x_{n}^{M}\\
# \end{bmatrix}
# $
#
#
# -----------
# It is easy to see:
#
# $A\omega = B$
#
# $A^{-1}A\omega = A^{-1}B$
#
# $\omega = A^{-1}B$
#
# Finally.
#
# w^{\*} = A^{-1}{B}
#
# **Note**
#
# i = identity matrix
#
# $A^{-1}$ the inverse matrix A.
#
# $AA^{-1}=i$
# $A^{-1}A=i$
